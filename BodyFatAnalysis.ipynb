# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
# %matplotlib inline

# %%
#import
x = pd.read_csv(r'C:\Users\Nicholas Jones\Desktop\PythonStuff\bodyfat.csv')

# %%
#duplicates
x.duplicated().sum()
# Out:
# 0

# %%
#nulls
x.notnull().sum()
# Out:
# Density    252
# BodyFat    252
# Age        252
# Weight     252
# Height     252
# Neck       252
# Chest      252
# Abdomen    252
# Hip        252
# Thigh      252
# Knee       252
# Ankle      252
# Biceps     252
# Forearm    252
# Wrist      252
# dtype: int64

# %%
x
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
##Calcilating BMI ----------> kg/m^2
W = []
H = []
for n in range(len(x.iloc[:,3])):
    m = x.iloc[n,3]
    W.append(m)
#print(W)
for n in range(len(x.iloc[:,4])):
    s = x.iloc[n,4]
    H.append(s)
#print(H)
W = np.array(W)
Weight = W/2.2
H = np.array(H)
Height = (.0254*H)*(.0254*H)
#print(Weight, Height)
bmi_calc = Weight/Height
print(bmi_calc)
# Out:
# [ 23.67644312  23.38338748  24.72059056  24.93553153  25.57099605
#   26.51084047  26.21199261  23.59101032  24.57422406  25.8552299
#   23.6425122   26.34732039  26.32797658  28.48546507  27.38547149
#   26.32346236  27.35866863  29.24547336  28.2045149   27.61586346
#   27.27376483  29.03593657  21.21326144  21.38802979  23.21596125
#   21.9471051   20.33424693  22.88569236  22.39224092  23.78826052
#   23.57529982  22.24017431  23.31575216  30.53828401  32.24567764
#   31.97558843  29.08053126  29.7590673   49.01400961  31.86077374
#   39.16581838 165.9662247   31.2013611   29.21686832  19.08401701
#   21.5675099   20.64351304  20.6094595   20.38302237  20.16125351
#   21.35885177  20.60662692  21.06704583  19.92124271  21.06875395
#   26.90977604  27.65468334  29.35459993  28.50243901  29.29457965
#   28.36275275  26.83952302  27.58904905  27.93703313  29.54783275
#   28.37516587  21.32404697  21.32693572  22.80877386  21.60256656
# ...

# %%
#New Column 
x["bmi"] = bmi_calc

# %%
x.to_csv(r'C:\Users\Nicholas Jones\Desktop\bmi.csv')

# %%
#correlations
corr = x.corr()
print(corr)
# Out:
#              Density   BodyFat       Age    Weight    Height      Neck  \
# Density     1.000000 -0.987782 -0.277637 -0.594062  0.097881 -0.472966
# BodyFat    -0.987782  1.000000  0.291458  0.612414 -0.089495  0.490592
# Age        -0.277637  0.291458  1.000000 -0.012746 -0.171645  0.113505
# Weight     -0.594062  0.612414 -0.012746  1.000000  0.308279  0.830716
# Height      0.097881 -0.089495 -0.171645  0.308279  1.000000  0.253710
# Neck       -0.472966  0.490592  0.113505  0.830716  0.253710  1.000000
# Chest      -0.682599  0.702620  0.176450  0.894191  0.134892  0.784835
# Abdomen    -0.798955  0.813432  0.230409  0.887995  0.087813  0.754077
# Hip        -0.609331  0.625201 -0.050332  0.940884  0.170394  0.734958
# Thigh      -0.553091  0.559608 -0.200096  0.868694  0.148436  0.695697
# Knee       -0.495040  0.508665  0.017516  0.853167  0.286053  0.672405
# Ankle      -0.264890  0.265970 -0.105058  0.613685  0.264744  0.477892
# ...
